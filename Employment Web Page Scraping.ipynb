# %% [markdown]
# ### Employment Web Page Scraping and Comparison for IT Job Postings by Raffi Sahakyan

# %% [markdown]
# __Task:__ Challenge the claim that _Staff.am_ currently has significantly higher percentage of IT job announcements than _Careercenter.am_ with any method or approach you find suitable. Your submission must include your code and report providing the description of methodology and analysis of results. You are required to complete the task in Python.

# %% [markdown]
# Task Implementation Steps:
#     1) Scrape both wep pages with BeautifulSoup for job postings
#     2) Count the number of occurences of IT job announcements
#     3) Hypothesis Testing

# %%
#Basic Necessary Libraries
import numpy as np
import pandas as pd
from itertools import chain
import time
from collections import Counter

#Text Modules Applied
from textblob import TextBlob, Word

#Scraping Modules
import urllib.request
import requests
from urllib.request import urlopen
import bs4
from bs4 import BeautifulSoup

# %% [markdown]
# #### 1.1 Scraping careercenter.am with BeutifulSoup

# %%
url_cc = "http://www.careercenter.am/ccidxann.php"
html_cc = urlopen(url_cc)
soup_cc = BeautifulSoup(html_cc, 'lxml')
bs4.BeautifulSoup
title_cc = soup_cc.title
print(title_cc)
# Out:
# <title>Career Center - Announcements Index</title>

# %%
all_tables_cc = soup_cc.find_all('table')
print(soup_cc.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
#  <head>
#   <script type="text/javascript">
#    <!--
#     if (parent.location.href == self.location.href){
#       window.location.href = '/';
#     } //-->
#   </script>
#   <meta content="Custom PHP script by http://www.bartellonline.com/" name="generator"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    Career Center - Announcements Index
#   </title>
#   <base target="main"/>
#   <style type="text/css">
#    body { background: FFFAA9; margin-left: 3px; font-family: Verdana; font-size: 13px; }
#     table { font-family: Verdana; font-size: 13px; }
#     p { margin-bottom: 5px; margin-top: 5px; }
#   </style>
#  </head>
#  <body bgcolor="#FFFAA9">
#   <p align="center">
#    <i>
#     <a name="TOP">
#      - Last updated:
#     </a>
#     13 Dec 2018 10:07:52 -
#    </i>
#   </p>
#   <p>
#    <strong>
#     AVAILABLE TODAY:
#    </strong>
#   </p>
#   <p>
#    &amp;nbsp
#    <img alt="bullet" border="0" height="6" src="images/bullet_sl.jpg" width="6"/>
#    <a href="/ccidxann.php#JO" target="_self">
#     <strong>
#      JOB OPPORTUNITIES
#     </strong>
#    </a>
#    (148)
#    <br/>
#   </p>
#   <p>
#    &amp;nbsp
#    <img alt="bullet" border="0" height="6" src="images/bullet_sl.jpg" width="6"/>
#    <a href="/ccidxann.php#IO" target="_self">
#     <strong>
#      INTERNSHIPS
#     </strong>
#    </a>
#    (1)
#    <br/>
#   </p>
#   <p>
#    &amp;nbsp
#    <img alt="bullet" border="0" height="6" src="images/bullet_sl.jpg" width="6"/>
#    <a href="/ccidxann.php#TG" target="_self">
#     <strong>
#      TRAININGS
#     </strong>
#    </a>
#    (3)
#    <br/>
#   </p>
#   <p>
#    &amp;nbsp
#    <img alt="bullet" border="0" height="6" src="images/bullet_sl.jpg" width="6"/>
#    <a href="/ccidxann.php#NW" target="_self">
#     <strong>
#      NEWS
#     </strong>
#    </a>
#    (1)
#    <br/>
#   </p>
#   <br/>
#   <table border="0" width="100%">
#    <tr>
#     <td align="center" colspan="2">
#      <strong>
#       <a name="JO">
#        JOB OPPORTUNITIES
#       </a>
#      </strong>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33494" title="Application Deadline: 12 January 2019">
#       Support Center Specialist / VXSoft
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33491" title="Application Deadline: 11 January 2019">
#       Technical Writer / VXSoft
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33490" title="Application Deadline: 11 January 2019">
#       Web Developer / VXSoft
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33484" title="Application Deadline: 11 January 2019">
#       Corporate Customer Attraction Manager / RESO Insurance
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33483" title="Application Deadline: 11 January 2019">
#       Underwriter/ Agency Network Specialist / RESO Insurance
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33478" title="Application Deadline: 11 January 2019">
#       Revenue Accounting Manager / OMD
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33437" title="Application Deadline: 11 January 2019">
#       Senior QA Engineer / BG Solutions
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33438" title="Application Deadline: 11 January 2019">
#       Senior Full Stack Developer / BG Solutions
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33480" title="Application Deadline: 26 December 2018">
#       National Office Supply Chain Team Lead / World Vision Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33476" title="Application Deadline: 11 January 2019">
#       C#/ АSP. NET Developer  / Carpisa
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33482" title="Application Deadline: 11 January 2019">
#       Client Manager / Forex Club
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33446" title="Application Deadline: 11 January 2019">
#       React.js Developer / InScope
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33471" title="Application Deadline: 11 January 2019">
#       Branch Credit Specialist / Evocabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33467" title="Application Deadline: 10 January 2019">
#       Marketing Manager / AMarkets
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33461" title="Application Deadline: 10 January 2019">
#       Assistant to the Director / Chess Academy of Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33470" title="Application Deadline: 28 December 2018">
#       Chief Accountant / Divisa AM
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33472" title="Application Deadline: 10 January 2019">
#       Technical Writer / Intelligent Digital Technologies
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33473" title="Application Deadline: 10 January 2019">
#       Database Developer / Intelligent Digital Technologies
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33449" title="Application Deadline: 23 December 2018">
#       Accountant / Fast Credit Capital UCO
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33469" title="Application Deadline: 26 December 2018">
#       Bookkeeper / UWC Dilijan College
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33465" title="Application Deadline: 07 January 2019">
#       Head of Sales Unit / Varks.am
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33466" title="Application Deadline: 28 December 2018">
#       Contact Center Manager / CMX Solutions
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33457" title="Application Deadline: 10 January 2019">
#       IT Project Manager / VXSoft
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33460" title="Application Deadline: 10 January 2019">
#       Manual QA Engineer / Praemium RA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33459" title="Application Deadline: 10 January 2019">
#       Full Stack .NET Developer / Praemium RA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33458" title="Application Deadline: 10 January 2019">
#       UI Developer / Praemium RA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33452" title="Application Deadline: 09 January 2019">
#       Chief Accountant / Daroink
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33447" title="Application Deadline: 09 January 2019">
#       Python Backend Developer / Threatify
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33433" title="Application Deadline: 28 December 2018">
#       Accountant / Prima Finance
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33386" title="Application Deadline: 09 January 2019">
#       Front End Developer / Urbanlinx Media
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33448" title="Application Deadline: 30 December 2018">
#       Designer / Mikshin
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33445" title="Application Deadline: 06 January 2019">
#       Full Stack Developer / Intertech
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33413" title="Application Deadline: 06 January 2019">
#       Affiliate/ Partners Manager / AMarkets
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33419" title="Application Deadline: 06 January 2018">
#       Marketing and Social Media Manager / AMarkets
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33434" title="Application Deadline: 20 December 2018">
#       IT Specialist / Lanar Service
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33444" title="Application Deadline: 28 December 2018">
#       Risk Manager / Mogo UCO
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33443" title="Application Deadline: 06 January 2018">
#       Logistics Manager / Mira Trans
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33442" title="Application Deadline: 06 January 2019">
#       Market Development Officer / Mira Trans
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33440" title="Application Deadline: 24 December 2018">
#       Technical Support Specialist / Ucom
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33431" title="Application Deadline: 29 December 2018">
#       Project Manager in Armenia / IPC - Internationale Projekt Consult
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33427" title="Application Deadline: 16 December 2018">
#       Internal Security Specialist, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33421" title="Application Deadline: 16 December 2018">
#       Client Manager, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33425" title="Application Deadline: 16 December 2018">
#       Cashier, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33426" title="Application Deadline: 16 December2018">
#       Receptionist, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33423" title="Application Deadline: 16 December 2018">
#       Loan Officer, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33424" title="Application Deadline: 16 December 2018">
#       Teller, Abovyan Branch / Ameriabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33422" title="Application Deadline: 19 December 2018">
#       Manual QA Engineer / Intelligent Digital Technologies
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33409" title="Application Deadline: 04 January 2019">
#       Payroll and Personnel Specialist / LC Waikiki
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33414" title="Application Deadline: 04 January 2019">
#       Manual QA Engineer / Lite-Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33416" title="Application Deadline: 04 January 2019">
#       .NET MVC Developer / Lite-Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33415" title="Application Deadline: 04 January 2019">
#       Front End Developer / Lite-Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33418" title="Application Deadline: 04 January 2019">
#       Lighting Systems Engineer / Consel
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33412" title="Application Deadline: 19 December 2018">
#       Administrative Assistant/ Translator / Shen
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33410" title="Application Deadline: 03 January 2019">
#       Junior Finance Officer / Dexatel
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33407" title="Application Deadline: 28 December 2018">
#       Marketing Manager / Deltapro
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33406" title="Application Deadline: 03 January 2019">
#       Measuring Engineer / Deltapro
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33408" title="Application Deadline: 19 December 2018, 5p.m.">
#       Pre-Service Training Language and Cultural Facilitator / US Peace Corps Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33401" title="Application Deadline: 03 January 2019">
#       Sales Executive / Ramada Hotel and Suites Yerevan
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33399" title="Application Deadline: 03 January 2019">
#       Marketing Manager / Master ADV
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33391" title="Application Deadline: 25 December 2018">
#       Java Developer / Catches
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33390" title="Application Deadline: 20 December 2018">
#       Senior Web Developer / Kinetics SDMA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33387" title="Application Deadline: 25 December 2018">
#       Farsi Speaking Customer Support Agent / Rika Group UK
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33384" title="Application Deadline: 28 December 2018">
#       Administrative Assistant / Nork-Marash Medical Center
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33394" title="Application Deadline: 13 December 2018">
#       Head of Corporate Customer Relations Division / Ardshinbank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33398" title="Application Deadline: 13 December 2018">
#       Senior Financial Consultant, SME Customer Relations Division / Ardshinbank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33396" title="Application Deadline: 13 December 2018">
#       Responsible for POS-terminal Service Sales, SME Customer Relations Division / Ardshinbank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33397" title="Application Deadline: 13 December 2018">
#       Responsible for Premium Customers Relations, Corporate Customer Relations Division / Ardshinbank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33393" title="Application Deadline: 13 December 2018">
#       Financial Consultant in POS-terminal Service Sales, SME Customer Relations Division / Ardshinbank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33392" title="Application Deadline: 31 December 2018">
#       Medical Representative, Rx/OTC / Sandoz Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33382" title="Application Deadline: 17 December 2018">
#       Bookkeeper / Avenue Consulting Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33381" title="Application Deadline: 17 December 2018">
#       Accountant / Avenue Consulting Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33388" title="Application Deadline: 14 December 2018">
#       Administrative Assistant / Savings Banks Foundation for International Cooperation
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33372" title="Application Deadline: 29 December 2018">
#       Software Engineer, Management Applications Team / BlueNet
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33373" title="Application Deadline: 29 December 2018">
#       Software Engineer, Infrastructure System Team / BlueNet
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33371" title="Application Deadline: 29 December 2018">
#       Software Engineer, Session Initiation Protocol Team / BlueNet
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33376" title="Application Deadline: 29 December 2018">
#       Chief Accountant / Slavmed Medical Center
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33378" title="Application Deadline: 29 December 2018">
#       Learning and Development Manager / Yeremyan Projects
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33374" title="Application Deadline: 29 December 2018">
#       Front End Developer / Kinetics SDMA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33383" title="Application Deadline: 29 December 2018">
#       IT Project Manager / Varks.am
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33359" title="Application Deadline: 29 December 2018">
#       Merchandiser / Grand Candy
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33368" title="Application Deadline: 28 December 2018">
#       Reporting Responsible / Armenia International Airports
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33361" title="Application Deadline: 20 December 2018">
#       Aurora Humanitarian Initiative Partnerships Director / IDeA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33369" title="Application Deadline: 28 December 2018">
#       Brand Manager / Barsis
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33357" title="Application Deadline: 28 December 2018">
#       Customer Support Team Lead / FXTM Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33358" title="Application Deadline: 28 December 2018">
#       Software Support Consultant/ Trainer / Ogma Applications
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33363" title="Application Deadline: 22 December 2018">
#       Marketing Specialist / Armenia Travel + M
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33348" title="Application Deadline: 16 December 2018">
#       Milk Technologist/ Consultant / Strategic Development Agency
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33349" title="Application Deadline: 27 December 2018">
#       Accountant / Mikshin
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33337" title="Application Deadline: 27 December 2018">
#       Linux System Administrator / Home TV
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33347" title="Application Deadline: 27 December 2018">
#       Training Consultant / Ogma Applications
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33345" title="Application Deadline: 27 December 2018">
#       Senior Product Manager / PicsArt
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33346" title="Application Deadline: 27 December 2018">
#       Debt Collection Specialist / GoodCredit UCO
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33343" title="Application Deadline: 17 December 2018">
#       Junior Associate/ Lawyer / Concern-Dialog
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33344" title="Application Deadline: 16 December 2018">
#       Information Security Specialist / ID Bank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33338" title="Application Deadline: 26 December 2018">
#       PPC Manager / Andava Digital Marketing Agency
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33339" title="Application Deadline: 26 December 2018">
#       Social Media Marketing Manager / Andava Digital Marketing Agency
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33340" title="Application Deadline: 16 December 2018">
#       Program Mortgage Loan Specialist / Evocabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33342" title="Application Deadline: 16 December 2018">
#       C# Software Developer / Evocabank
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33336" title="Application Deadline: 26 December 2018">
#       Data Analyst / Seven Smarts
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33335" title="Application Deadline: 26 December 2018">
#       Digital Marketing Officer / Breavis
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33334" title="Application Deadline: 25 December 2018">
#       Senior Automation QA Engineer / Intelligent Digital Technologies
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33331" title="Application Deadline: 25 December 2018">
#       Head of  Marketing / Yeremyan Projects
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33330" title="Application Deadline: 25 December 2018">
#       Service Mechanic / Epiroc Central Asia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33333" title="Application Deadline: 25 December 2018">
#       Auditor / IFP
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33316" title="Application Deadline: 22 December 2018">
#       International Sales Manager / Sirtel
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33326" title="Application Deadline: 15 December 2018">
#       Executive Assistant / Sef International UCO
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33325" title="Application Deadline: 22 December 2018">
#       Chief Financial Officer / Menu Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33320" title="Application Deadline: 22 December 2018">
#       Incoming Tour Manager / Armenia Travel + M
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33324" title="Application Deadline: 21 December 2018">
#       Contact Center Specialist / Varks.am
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33319" title="Application Deadline: 22 December 2018">
#       Automation Test Engineer / Ucom
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33312" title="Application Deadline: 21 December 2018">
#       UI/ UX Designer / Menu Group
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33314" title="Application Deadline: 21 December 2018">
#       Information Security Officer / Byblos Bank Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33313" title="Application Deadline: 21 December 2018">
#       Digital Marketing Designer / Ucom
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33310" title="Application Deadline: 21 December 2018">
#       Marketing Communications Officer / Breavis
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33311" title="Application Deadline: 21 December 2018">
#       Design and Art Officer / Breavis
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33308" title="Application Deadline: 21 December 2018">
#       Junior React.js Developer / Mandal.AI
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33309" title="Application Deadline: 21 December 2018">
#       Product Owner / Ginosi Apartels &amp; Hotels
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33295" title="Application Deadline: 20 December 2018">
#       Financial Director / Lesona
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33294" title="Application Deadline: 20 December 2018">
#       Brand Manager / Lesona
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33278" title="Application Deadline: 18 December 2018">
#       Medical Representative / Les Laboratoires Servier Armenia RO
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33297" title="Application Deadline: 20 December 2018">
#       Manual QA Specialist / Renderforest
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33277" title="Application Deadline: 20 December 2018">
#       Bartender/ Waiter / Republic Square Boutique Hotel
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33283" title="Application Deadline: 20 December 2018">
#       Senior Software Engineer / Ogma Applications
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33259" title="Application Deadline: 19 December 2018">
#       Senior Data Analyst / BG Solutions
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33280" title="Application Deadline: 19 December 2018">
#       Receptionist/ Translator / BDO Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33275" title="Application Deadline: 19 December 2018">
#       Accountant / Hayantar
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33272" title="Application Deadline: 19 December 2018">
#       Project Manager / IDeA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33265" title="Application Deadline: 19 December 2018">
#       CNC Machine Operator / AM Stone
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33269" title="Application Deadline: 18 December 2018">
#       Commercial Manager/ Negotiator / Intertech
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33260" title="Application Deadline: 18 December 2018">
#       Graphic Designer / Yeremyan Projects
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33261" title="Application Deadline: 18 December 2018">
#       Creative Manager / Yeremyan Projects
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33266" title="Application Deadline: 15 December 2018">
#       HR Manager / Deltapro
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33268" title="Application Deadline: 18 December 2018">
#       Head of Administration and Technical Support Division, IT Department / Rosgosstrakh-Armenia
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33267" title="Application Deadline: 18 December 2018">
#       Senior QA Engineer / Zangi
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33254" title="Application Deadline: 15 December 2018">
#       Marketing Manager / Zangak Bookstore
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33217" title="Application Deadline: 15 December 2018">
#       Infrastructure Administrator / Praemium RA
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33250" title="Application Deadline: 15 December 2018">
#       Sales Consultant / Living's
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33244" title="Application Deadline: 14 December 2018">
#       Brand/ Import Manager / MBM
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33242" title="Application Deadline: 14 December 2018">
#       Assistant to Accountant / Aras Food
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33239" title="Application Deadline: 14 December 2018">
#       Manual QA Engineer / CargoMatrix
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33170" title="Application Deadline: 14 December 2018">
#       Dentist / Luxury Smile
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33237" title="Application Deadline: 13 December 2018">
#       System Administrator/ DevOps Engineer / Zero
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33238" title="Application Deadline: 13 December 2018">
#       .NET Developer / Zero
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33362" title="Application Deadline: 13 December 2018">
#       Customer Support Specialist / Hosteeva
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33230" title="Application Deadline: 13 December 2018">
#       Research Associate/ Data Scientist / Foundation for Armenian Science and Technology
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33229" title="Application Deadline: 13 December 2018">
#       Principal/ Data Scientist / Foundation for Armenian Science and Technology
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33228" title="Application Deadline: 13 December 2018">
#       Origination Partner/ Data Scientist / Foundation for Armenian Science and Technology
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33234" title="Application Deadline: 13 December 2018">
#       Leading Specialist, Payment/ Settlement (Card) System Relations Group / Converse Bank
#      </a>
#     </td>
#    </tr>
#   </table>
#   <p align="right">
#    <a href="/ccidxann.php#TOP" target="_self">
#     <font size="-2">
#      Go To Top
#     </font>
#    </a>
#   </p>
#   <table border="0" width="100%">
#    <tr>
#     <td align="center" colspan="2">
#      <strong>
#       <a name="IO">
#        INTERNSHIPS
#       </a>
#      </strong>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33428" title="Application Deadline: 19 December 2018">
#       ABAP/Java/RPA Intern, Consulting Department / Deloitte Armenia
#      </a>
#     </td>
#    </tr>
#   </table>
#   <p align="right">
#    <a href="/ccidxann.php#TOP" target="_self">
#     <font size="-2">
#      Go To Top
#     </font>
#    </a>
#   </p>
#   <table border="0" width="100%">
#    <tr>
#     <td align="center" colspan="2">
#      <strong>
#       <a name="TG">
#        TRAININGS
#       </a>
#      </strong>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33291" title="Application Deadline: Classes are starting monthly as soon as there are 4-6 people.">
#       Intensive "TOEFL iBT" and "TOEFL ITP" Preparation Courses / Career Center
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33290" title="Application Deadline: Rolling (Groups start their classes as soon as there are 4-6 people).">
#       English Language Courses / Career Center
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33289" title="Application Deadline: Rolling (Groups start their classes as soon as there are 4-6 people).">
#       Russian Language Courses / Career Center
#      </a>
#     </td>
#    </tr>
#   </table>
#   <p align="right">
#    <a href="/ccidxann.php#TOP" target="_self">
#     <font size="-2">
#      Go To Top
#     </font>
#    </a>
#   </p>
#   <table border="0" width="100%">
#    <tr>
#     <td align="center" colspan="2">
#      <strong>
#       <a name="NW">
#        NEWS
#       </a>
#      </strong>
#     </td>
#    </tr>
#    <tr>
#     <td valign="top" width="8">
#      <img alt="bullet" border="0" height="6" src="images/bullet_fs.jpg" vspace="6" width="6"/>
#     </td>
#     <td>
#      <a href="ccdspann.php?id=33292">
#       English Language Courses for Schoolchildren / Career Center
#      </a>
#     </td>
#    </tr>
#   </table>
#   <p align="right">
#    <a href="/ccidxann.php#TOP" target="_self">
#     <font size="-2">
#      Go To Top
#     </font>
#    </a>
#   </p>
#  </body>
# </html>

# %%
job_cc=[]
all_links_cc=soup_cc.find_all('a')
for link in all_links_cc:
    job_cc.append(link.get_text())

# %%
list_to_remove=['- Last updated: ',
 'JOB OPPORTUNITIES',
 'INTERNSHIPS',
 'TRAININGS',
 'NEWS',
 'JOB OPPORTUNITIES','INTERNSHIPS','TRAININGS','Go To Top',
 'NEWS',
 'English Language Courses for Schoolchildren / Career Center',
 'Go To Top']
job_cc = list(set(job_cc).difference(set(list_to_remove)))

# %%
company_cc = []
employment_cc = []

for i in job_cc:
    employment_cc.append(i.split(" / ")[0])
    company_cc.append(i.split(' / ')[1])
employment_cc = [i.lower() for i in employment_cc]

# %%
#Creating the Dataframe for Careercenter.am
cc_df = pd.DataFrame({"Employment_CC":employment_cc, "Company_CC":company_cc})
cc_df.head(2)
# Out:
#                   Employment_CC  Company_CC
# 0               ui/ ux designer  Menu Group
# 1  receptionist, abovyan branch  Ameriabank

# %% [markdown]
# #### 1.2 Scraping Staff.am with BeutifulSoup

# %%
def custom_scraper(url):
    response = requests.get(url)
    page = response.content
    page = BeautifulSoup(page,"html.parser")
    
    titles = page.find_all("div", class_="job-inner job-item-title")
    job = [i.find("p").get_text() for i in titles]
    return job

# %%
end_page_staff = 15
url_base_staff = "https://staff.am/en/jobs?page="
job_staff = []

# %%
#To iterate over the search pages in the webpage
for i in range(1,end_page_staff):
    url = url_base_staff + str(i)
    job = custom_scraper(url)
    job_staff.append(job)

# %%
employment_staff = list(chain.from_iterable(job_staff))
employment_staff = [i.lower() for i in employment_staff]

# %% [markdown]
# #### 2 Count the IT Job Announcements

# %%
#IT tags retrieved from web search of IT Professions
IT_tags = ['ios developer','node.js developer', 'systems control senior specialist', 'manual qa engineer', 'c++ developer', 'scrum master', 'qa engineer', 'sql developer','python developer','c++ developer','git developer', 'angular developer', 'web qa (developer)', 'react native developer', '.net developer (full stack)', 'python backend developer - remote','react developer', 'software developer', 'R developer','android developer', 'blockchain developer','c# developer','c# software developer','java developer','manual qa engineer', 'qa specialist', 'qa automation engineer', 'automation qa engineer','manual qa engineer','qa engineer','qa intern','quality control manager', 'senior qa engineer','middle qa engineer','ui/ux designer', 'product manager','senior product manager', 'project manager','product owner','scrum master', 'technical project manager','web developer','php developer','js developer','mid/senior mvc developer','php/js developer','backend developer','angular developer'] 

#Creating a Counter object to count over the IT tags
word_counts_staff = Counter(employment_staff)
total_IT_staff = sum(word_counts_staff.get(w,0) for w in IT_tags)
prop_IT_staff = total_IT_staff/len(employment_staff)
print("There are total of "+str(total_IT_staff)+" IT job postings in Staff.am, "+ str(round(prop_IT_staff*100,2))+'% of Total.')

word_counts_cc = Counter(employment_cc)
total_IT_cc = sum(word_counts_cc.get(w,0) for w in IT_tags)
prop_IT_cc = total_IT_cc/len(employment_cc)
print("-"*100)
print("There are total of "+str(total_IT_cc)+" IT job postings in Careercenter.am, "+ str(round(prop_IT_cc*100,2))+'% of Total.')
# Out:
# There are total of 80 IT job postings in Staff.am, 15.56% of Total.
# ----------------------------------------------------------------------------------------------------
# There are total of 20 IT job postings in Careercenter.am, 13.16% of Total.

# %% [markdown]
# #### 3 Hypothesis Testing

# %% [markdown]
# Hypothesis Formulation
#
# H0: IT Job Postings Proportion by Staff.am > IT Job Postings Proportion by Careercenter.am
#
#
# H1: IT Job Postings Proportion by Staff.am <= IT Job Postings Proportion by Careercenter.am

# %% [markdown]
# Significance Level Formulation
#
# Degree of significance, $\alpha$ % = 5%
#
# Level of significance, $\alpha$ = 0.05

# %%
listofvalues_cc = [0]*(len(employment_cc)-total_IT_cc)+[1]*total_IT_cc
listofvalues_staff = [0]*(len(employment_staff)-total_IT_staff)+[1]*total_IT_staff

# %%
hypothesis_df = pd.DataFrame({"Sample Size":[len(employment_cc),len(employment_staff)],
                              "Average Number of IT Job Postings": [np.mean(listofvalues_cc),np.mean(listofvalues_staff)],
                              'Sample Standard Deviation':[np.std(listofvalues_cc),np.std(listofvalues_staff)]},
                             index=['CC.am','Staff.am'])
hypothesis_df
# Out:
#           Sample Size  Average Number of IT Job Postings  \
# CC.am             152                           0.131579
# Staff.am          514                           0.155642
#
#           Sample Standard Deviation
# CC.am                      0.338032
# Staff.am                   0.362516

# %%
t_score = (np.mean(listofvalues_cc)-np.mean(listofvalues_staff))/(np.sqrt(np.var(listofvalues_cc)/len(employment_cc)-np.var(listofvalues_staff)/len(employment_staff)))
t_score = abs(t_score)
print("t score with unknown population variance: " + str(round(t_score,2)))
# Out:
# t score with unknown population variance: 1.08

# %%
degrees_of_freedom = min([hypothesis_df['Sample Size'][0]-1,hypothesis_df['Sample Size'][1]-1])
print("Degrees of freedom for t-statistic: " + str(degrees_of_freedom))
t_stat = 1.66 #t statistic with 100 degrees of freedom for a=0.05 one tail test
print("Comparison of t score with t stat: " + str(t_score>t_stat))
# Out:
# Degrees of freedom for t-statistic: 151
# Comparison of t score with t stat: False

# %% [markdown]
# This test has not provided statistically significant evidence that proportion of IT Job Postings in Staff.am is more than that in Careercenter.am
